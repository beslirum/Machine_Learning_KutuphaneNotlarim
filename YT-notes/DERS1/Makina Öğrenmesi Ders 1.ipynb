# %%
#Makine Öğrenmesi

# %%
"""
- Bilgisayar sistemlerinin veri analizi yaparak örüntüler keşfetmesini ve gelecekteki veriler üzerinde tahminler yapmasını sağlayan bir alandır.
- Veri analizi, model oluşturma ve performans değerlendirmesi gibi adımları içerir.
- Örnekler: Görüntü tanıma, spam filtreleme, pazar sepeti analizi gibi uygulamalar.
"""
# Out:
# '\n- Bilgisayar sistemlerinin veri analizi yaparak örüntüler keşfetmesini ve gelecekteki veriler üzerinde tahminler yapmasını sağlayan bir alandır.\n- Veri analizi, model oluşturma ve performans değerlendirmesi gibi adımları içerir.\n- Örnekler: Görüntü tanıma, spam filtreleme, pazar sepeti analizi gibi uygulamalar.\n'

# %%
# Linear Regresyon:

# %%
"""
- Bir bağımlı değişken ile bir veya daha fazla bağımsız değişken arasındaki ilişkiyi modellemek için kullanılan bir tekniktir.
- İlişki doğrusal olduğunda (yani bir doğru tarafından açıklanabilir), bu model kullanılır.
- Temelde, veri setindeki gözlemleri en iyi şekilde temsil eden bir doğru denklemi oluşturur.
- Örnekler: Ev fiyat tahmini, gelir tahmini, pazarlama verimliliği tahmini gibi uygulamalar.
- Formül: Y = b0 + b1*X1 + b2*X2 + ... + bn*Xn
    - Y: Bağımlı değişken
    - X1, X2, ..., Xn: Bağımsız değişkenler
    - b0, b1, b2, ..., bn: Katsayılar
"""
# Out:
# '\n- Bir bağımlı değişken ile bir veya daha fazla bağımsız değişken arasındaki ilişkiyi modellemek için kullanılan bir tekniktir.\n- İlişki doğrusal olduğunda (yani bir doğru tarafından açıklanabilir), bu model kullanılır.\n- Temelde, veri setindeki gözlemleri en iyi şekilde temsil eden bir doğru denklemi oluşturur.\n- Örnekler: Ev fiyat tahmini, gelir tahmini, pazarlama verimliliği tahmini gibi uygulamalar.\n- Formül: Y = b0 + b1*X1 + b2*X2 + ... + bn*Xn\n    - Y: Bağımlı değişken\n    - X1, X2, ..., Xn: Bağımsız değişkenler\n    - b0, b1, b2, ..., bn: Katsayılar\n'

# %%
# Uygulama:

# %%
"""
- Örneğin, ev fiyatı tahmini yaparken, evin özelliklerini (alanı, oda sayısı, konumu, vb.) kullanarak bir linear regresyon modeli oluşturabiliriz.
- Bu modeli eğitmek için geçmiş ev satış verilerini kullanırız.
- Ardından, yeni bir evin fiyatını tahmin etmek için bu modeli kullanabiliriz.
"""
# Out:
# '\n- Örneğin, ev fiyatı tahmini yaparken, evin özelliklerini (alanı, oda sayısı, konumu, vb.) kullanarak bir linear regresyon modeli oluşturabiliriz.\n- Bu modeli eğitmek için geçmiş ev satış verilerini kullanırız.\n- Ardından, yeni bir evin fiyatını tahmin etmek için bu modeli kullanabiliriz.\n'
